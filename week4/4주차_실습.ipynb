# %% [markdown]
# 생능 출판사 "으뜸 데이터 분석과 머신러닝"(개정판) 소스 코드 발췌 (저자 : 박동규, 강영민, 김병욱)

# %% [markdown]
# ### Series(시리즈)

# %%
import numpy as np
import pandas as pd

se = pd.Series([1, 2, np.nan, 4])   # np.nan은 "숫자가 아님(not a number)"을 나타내는 특별한 부동소수점 값
se
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# dtype: float64

# %%
# 인덱싱
print(se[0])
print(se[1])
# 슬라이싱
print(se[0:2])
# Out:
# 1.0
# 2.0
# 0    1.0
# 1    2.0
# dtype: float64

# %% [markdown]
# ### 인덱스를 가진 Series(시리즈)

# %%
import pandas as pd
import numpy as np

data = [1, 2, np.nan, 4]
indexed_se = pd.Series(data, index = ['a', 'b', 'c', 'd'])
print(indexed_se)
# Out:
# a    1.0
# b    2.0
# c    NaN
# d    4.0
# dtype: float64

# %%
indexed_se['a'], indexed_se['b']  # 인덱스가 'a', 'b',.. 임
# Out:
# (np.float64(1.0), np.float64(2.0))

# %% [markdown]
# ### Series와 DataFrame(데이터프레임)

# %%
import pandas as pd
import numpy as np

income = {'Jan' : 9500, 'Feb': 6200, 'Mar': 6050, 'Apr': 7000}
income_se = pd.Series(income)   #월을 인덱스로 하는 매출 시리즈
print('Income')
print(income_se)
# Out:
# Income
# Jan    9500
# Feb    6200
# Mar    6050
# Apr    7000
# dtype: int64

# %%
month_se = pd.Series(['Jan', 'Feb', 'Mar', 'Apr'])
income_se = pd.Series([9500, 6200, 6050, 7000])
expenses_se = pd.Series([5040, 2350, 2300, 4800])
df = pd.DataFrame( {'Month': month_se, 'Income': income_se,
                   'Expenses' : expenses_se})
df    # print(df)를 이용해서 출력형식을 비교해 보자
# Out:
#   Month  Income  Expenses
# 0   Jan    9500      5040
# 1   Feb    6200      2350
# 2   Mar    6050      2300
# 3   Apr    7000      4800

# %%
print(df)
# Out:
#   Month  Income  Expenses
# 0   Jan    9500      5040
# 1   Feb    6200      2350
# 2   Mar    6050      2300
# 3   Apr    7000      4800

# %%
print('Max monthly income:', income_se.max(),', Mean monthly income:', income_se.mean())
# Out:
# Max monthly income: 9500 , Mean monthly income: 7187.5

# %% [markdown]
# |### .csv 파일 읽기

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file)   # 웹에서 .csv 파일을 직접 읽기

# %%
print(df)
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
# 3      Japan  10.87  10.83   7.55   9.09   7.88
# 4      Korea   4.04   3.78   3.45   4.20   4.62
# 5     Mexico   2.01   2.05   1.50   2.25   2.54

# %%
df # jupyter notebook에서는 print() 없이도 DataFrame이 깔끔하게 출력됨

# %% [markdown]
# ### DataFrame(데이터프레임)

# %%
df = pd.read_csv(file, index_col = 0) #인덱스 열 지정
print(df)

# %%
df.columns   # 열 인덱스
# Out:
# Index(['2007', '2008', '2009', '2010', '2011'], dtype='str')

# %%
df.index     # 행 인덱스
# Out:
# Index(['China', 'EU', 'US', 'Japan', 'Korea', 'Mexico'], dtype='str')

# %% [markdown]
# ### 데이터 슬라이싱과 인덱싱

# %%
df['2008']   # 데이터프레임의 2008년도 열 값들을 살펴보자
# Out:
# China      7.95
# EU        17.71
# US         8.45
# Japan     10.83
# Korea      3.78
# Mexico     2.05
# Name: 2008, dtype: float64

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col=0)   # 원격지에 접속하여 csv를 읽어옴
df_3 = df.head(3)     # 첫 3행의 정보를 가져온다
df_3
# Out:
#         2007   2008   2009   2010   2011
# China   7.71   7.95  11.96  15.84  16.33
# EU     19.02  17.71  15.00  16.70  17.48
# US     10.47   8.45   5.58   7.60   8.40

# %%
#df[2:3] # 2열의 데이터를 가지고 온다.
df[2:3]
# Out:
#      2007  2008  2009  2010  2011
# US  10.47  8.45  5.58   7.6   8.4

# %%
# 인덱스로 인덱싱하기 위해서 loc 함수 사용 row 에 해당하는 인덱싱인 경우
df.loc['Korea']
# Out:
# 2007    4.04
# 2008    3.78
# 2009    3.45
# 2010    4.20
# 2011    4.62
# Name: Korea, dtype: float64

# %%
#여러 행을 가지고 오고 싶으면 인덱스의 리스트 형태로
df.loc[['US', 'Korea']]
# Out:
#         2007  2008  2009  2010  2011
# US     10.47  8.45  5.58   7.6  8.40
# Korea   4.04  3.78  3.45   4.2  4.62

# %%
#열에 대한 인덱싱, 행에 대한 인덱싱을 동시에 가능
df['2011'].iloc[[0, 4]]
# Out:
# China    16.33
# Korea     4.62
# Name: 2011, dtype: float64

# %%
df.loc[['China', 'Korea'], '2011']

# %%
df.head(3)['2009']     # 앞의 세 행에서 2009 열만 선택

# %%
df['2009'].head(3)   # 2009 열의 앞 세 행

# %% [markdown]
# ### loc와 iloc

# %%
df.iloc[4]  # 이 결과는 Series가 됨
# Out:
# 2007    4.04
# 2008    3.78
# 2009    3.45
# 2010    4.20
# 2011    4.62
# Name: Korea, dtype: float64

# %%
df.loc['Korea'] # 이 결과는 Series가 됨

# %%
df.iloc['Korea'] # 오류

# %%
df.loc[['US','Korea']]

# %%
df.loc['US','Korea'] # 오류

# %%
df.iloc[[2, 4]]  # 2번과 4번 행
# Out:
#         2007  2008  2009  2010  2011
# US     10.47  8.45  5.58   7.6  8.40
# Korea   4.04  3.78  3.45   4.2  4.62

# %%
df.iloc[2, 4]  # 2행 4열 데이터
# Out:
# np.float64(8.4)

# %%
df.iloc[2:4]     # 2번과 3번 행(파이썬 리스트 슬라이싱과 같음)

# %%
df.iloc[[2, 3]]    # df.iloc[2:4]와 같음

# %% [markdown]
# ### 데이터에 열 추가하기

# %%
df['total'] = df.sum(axis = 1) # df에 'total' 새 열 추가
df['mean'] = df.mean(axis=1)
print(df)
# Out:
#          2007   2008   2009   2010   2011  total       mean
# China    7.71   7.95  11.96  15.84  16.33  59.79  19.930000
# EU      19.02  17.71  15.00  16.70  17.48  85.91  28.636667
# US      10.47   8.45   5.58   7.60   8.40  40.50  13.500000
# Japan   10.87  10.83   7.55   9.09   7.88  46.22  15.406667
# Korea    4.04   3.78   3.45   4.20   4.62  20.09   6.696667
# Mexico   2.01   2.05   1.50   2.25   2.54  10.35   3.450000

# %%
df_new = df.sum(axis = 1)
df_new
# Out:
# China     139.510000
# EU        200.456667
# US         94.500000
# Japan     107.846667
# Korea      46.876667
# Mexico     24.150000
# dtype: float64

# %%
# DataFrame의 .sum과 .mean 메서드도 아래처럼 사용할 수 있음:
df['total'] = df[['2007', '2008', '2009', '2010', '2011']].sum(axis=1)
df['mean'] = df[['2007', '2008', '2009', '2010', '2011']].mean(axis=1)
print(df)

# %%
df.drop('2007', inplace=True, axis=1)
print(df)  # 위에서 계산한 mean과 total 값이 그대로 남아 있음

# %%
# 열을 삭제한 뒤 total과 mean 값을 다시 계산해야 함(자동으로 갱신되지 않음)
df['total'] = df[['2008', '2009', '2010', '2011']].sum(axis=1)
df['mean'] = df[['2008', '2009', '2010', '2011']].mean(axis=1)
print(df)

# %% [markdown]
# ### inplace=True로 DataFrame 갱신하기

# %%
import pandas as pd

d_df = pd.DataFrame(data = [[10, 20, 30, 40], [50, 60, 70, 80]],
                 columns = ['A', 'B', 'C', 'D'])
new_df = d_df.drop('B', axis=1, inplace=False)
print(new_df)    # B 열이 제거된 새로운 DataFrame
d_df
# Out:
#     A   C   D
# 0  10  30  40
# 1  50  70  80
#     A   B   C   D
# 0  10  20  30  40
# 1  50  60  70  80

# %%
print(d_df)         # d_df DataFrame은 바뀌지 않음

# %%
d_df.drop('B', axis=1, inplace=True) # inplace = True
print(d_df)   # d_df가 변경됨
# Out:
#     A   C   D
# 0  10  30  40
# 1  50  70  80

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col=0)
print(df)
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col=0)

df.drop('Mexico', axis=0, inplace=True) # Mexico 행 삭제
print(df)

# %% [markdown]
# ### DataFrame 시각화

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'

df = pd.read_csv(file, index_col = 0)

# %%
#df['2009'].plot(kind='bar', color=('orange','r', 'b', 'm', 'c', 'k')) 아래와 같음
df['2009'].plot.bar(color=('orange','r', 'b', 'm', 'c', 'k'))
# Out:
# <Axes: >

# %%
# df['2009'].plot(kind='pie')
df['2009'].plot.pie()
# Out:
# <Axes: >

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col=0)
df.plot.line()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df = df.transpose()  # df = df.T와 동일함
#df = df.T
print(df)
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
df.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# ### Pandas를 이용한 간단한 데이터 분석

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
weather_file = path + 'weather.csv'

weather = pd.read_csv(weather_file, index_col = 0, encoding='CP949') # 한글 인코딩용
print(weather)
print(weather.head(3))
print('weather data shape :', weather.shape)
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# 2010-08-05  27.2   9.1   5.6
# ...          ...   ...   ...
# 2020-07-27  22.1   4.2   1.7
# 2020-07-28  21.9   4.5   1.6
# 2020-07-29  21.6   3.2   1.0
# 2020-07-30  22.9   9.7   2.4
# 2020-07-31  25.7   4.8   2.5
#
# [3653 rows x 3 columns]
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# weather data shape : (3653, 3)

# %%
print(weather.describe())  # 계산을 할수있는데이터에 대해서 컬럼별로 데이터 갯수, 평균, 표준편차, 최소/최대값 등의 정보를 보여준다.
# mean() 평균
# std 표준편차
# Out:
#               평균기온         최대풍속         평균풍속
# count  3653.000000  3649.000000  3647.000000
# mean     12.942102     7.911099     3.936441
# std       8.538507     3.029862     1.888473
# min      -9.000000     2.000000     0.200000
# 25%       5.400000     5.700000     2.500000
# 50%      13.800000     7.600000     3.600000
# 75%      20.100000     9.700000     5.000000
# max      31.300000    26.000000    14.900000

# %%
print('평균 분석 -----------------------------')
print(weather.mean())
print('표준편차  분석 -----------------------------')
print(weather.std())
# Out:
# 평균 분석 -----------------------------
# 평균기온    12.942102
# 최대풍속     7.911099
# 평균풍속     3.936441
# dtype: float64
# 표준편차  분석 -----------------------------
# 평균기온    8.538507
# 최대풍속    3.029862
# 평균풍속    1.888473
# dtype: float64

# %% [markdown]
# ### 결측 데이터와 데이터 정리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
weather_file = path + 'weather.csv'
weather = pd.read_csv(weather_file, encoding='CP949', index_col=0)

# %%
weather.count() #Nan 인거 제외
# Out:
# 평균기온    3653
# 최대풍속    3649
# 평균풍속    3647
# dtype: int64

# %%
#weather['평균풍속'].isna() logical index
missing_data = weather[ weather['평균풍속'].isna() ]
missing_data
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2012-02-11  -0.7   NaN   NaN
# 2012-02-12   0.4   NaN   NaN
# 2012-02-13   4.0   NaN   NaN
# 2015-03-22  10.1  11.6   NaN
# 2015-04-01   7.3  12.1   NaN
# 2019-04-18  15.7  11.7   NaN

# %%
# 결측값을 0으로 채우기
weather.fillna(0, inplace = True)
print(weather.loc['2012-02-11'])
# Out:
# 평균기온   -0.7
# 최대풍속    0.0
# 평균풍속    0.0
# Name: 2012-02-11, dtype: float64

# %%
weather.fillna( weather['평균풍속'].mean(), inplace = True) # 결측치를 평균으로 채우기
print(weather.loc['2012-02-11'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 weather.fillna( weather['평균풍속'].mean(), inplace = True) # 결측치를 평균으로 채우기
#       2 print(weather.loc['2012-02-11'])
#
# NameError: name 'weather' is not defined

# %% [markdown]
# ### 시계열 데이터 분석을 위한 DatetimeIndex

# %%
import pandas as pd

d_list = ["01/03/2018", "01-03-2018", "2018-01-05", "2018/01/06"]
pd.DatetimeIndex(d_list).year    # 각 날짜의 연도 출력
#d_list
# Out:
# Index([2018, 2018, 2018, 2018], dtype='int32')

# %%
pd.DatetimeIndex(d_list).month   # 각 날짜의 월 출력
# Out:
# Index([1, 1, 1, 1], dtype='int32')

# %%
pd.DatetimeIndex(d_list).day     # 각 날짜의 일 출력
# Out:
# Index([3, 3, 5, 6], dtype='int32')

# %%
dt_list = ["01,03,2018 11:12:13", "01-03-2018 11:22:13"]
pd.DatetimeIndex(dt_list).hour     # 각 날짜의 시 출력
# Out:
# Index([11, 11], dtype='int32')

# %%
pd.DatetimeIndex(dt_list).minute   # 각 날짜의 분 출력
# Out:
# Index([12, 22], dtype='int32')

# %%
pd.to_datetime("01-03-2018") # datetime 이므로 년-월-일 로 전환
# Out:
# Timestamp('2018-01-03 00:00:00')

# %%
pd.to_datetime(dt_list)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10188\2216994671.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(dt_list)
# DatetimeIndex(['2018-01-01 11:12:13', '2018-01-03 11:22:13'], dtype='datetime64[us]', freq=None)

# %%
path = 'https://github.com/dongupak/DataML/raw/main/csv/'
weather_file = path + 'weather.csv'

weather = pd.read_csv(weather_file, encoding='CP949')
weather['년도'] = pd.DatetimeIndex(weather['일시']).year # dataframe 에 년도 추가
weather
# Out:
#               일시  평균기온  최대풍속  평균풍속    년도
# 0     2010-08-01  28.7   8.3   3.4  2010
# 1     2010-08-02  25.2   8.7   3.8  2010
# 2     2010-08-03  22.1   6.3   2.9  2010
# 3     2010-08-04  25.3   6.6   4.2  2010
# 4     2010-08-05  27.2   9.1   5.6  2010
# ...          ...   ...   ...   ...   ...
# 3648  2020-07-27  22.1   4.2   1.7  2020
# 3649  2020-07-28  21.9   4.5   1.6  2020
# 3650  2020-07-29  21.6   3.2   1.0  2020
# 3651  2020-07-30  22.9   9.7   2.4  2020
# 3652  2020-07-31  25.7   4.8   2.5  2020
#
# [3653 rows x 5 columns]

# %%
weather['month']=pd.DatetimeIndex(weather['일시']).month
weather.describe()
# Out:
#               평균기온         최대풍속         평균풍속           년도        month
# count  3653.000000  3649.000000  3647.000000  3653.000000  3653.000000
# mean     12.942102     7.911099     3.936441  2015.081577     6.522310
# std       8.538507     3.029862     1.888473     2.915180     3.449345
# min      -9.000000     2.000000     0.200000  2010.000000     1.000000
# 25%       5.400000     5.700000     2.500000  2013.000000     4.000000
# 50%      13.800000     7.600000     3.600000  2015.000000     7.000000
# 75%      20.100000     9.700000     5.000000  2018.000000    10.000000
# max      31.300000    26.000000    14.900000  2020.000000    12.000000

# %% [markdown]
# ### 데이터 구조를 바꾸는 pivot()

# %%
import pandas as pd

df = pd.DataFrame({'상품' : ['시계', '반지', '반지', '목걸이', '팔찌'],
                   '재질' : ['금', '은', '백금', '금', '은'],
                   '가격': [500000, 20000, 350000, 300000, 60000]})
df
# Out:
#     상품  재질      가격
# 0   시계   금  500000
# 1   반지   은   20000
# 2   반지  백금  350000
# 3  목걸이   금  300000
# 4   팔찌   은   60000

# %%
new_df = df.pivot(index='상품', columns='재질', values='가격')
new_df.fillna(value=0)
#new_df #Nan 이 생기는데, 이것을 처리하기 위해 fillna 로 결측치 처리가 가능하다.
# Out:
# 재질          금        백금        은
# 상품
# 목걸이  300000.0       0.0      0.0
# 반지        0.0  350000.0  20000.0
# 시계   500000.0       0.0      0.0
# 팔찌        0.0       0.0  60000.0

# %% [markdown]
# ### 데이터프레임을 병합하는 concat()

# %%
import pandas as pd

df_1 = pd.DataFrame( {'A' : ['a10', 'a11', 'a12'],
                      'B' : ['b10', 'b11', 'b12'],
                      'C' : ['c10', 'c11', 'c12']} ,
                      index = ['가', '나',  '다'] )

df_2 = pd.DataFrame( {'B' : ['b23', 'b24', 'b25'],
                      'C' : ['c23', 'c24', 'c25'],
                      'D' : ['d23', 'd24', 'd25']} ,
                      index = ['다', '라',  '마'] )

# %%
df_1
# Out:
#      A    B    C
# 가  a10  b10  c10
# 나  a11  b11  c11
# 다  a12  b12  c12

# %%
df_2
# Out:
#      B    C    D
# 다  b23  c23  d23
# 라  b24  c24  d24
# 마  b25  c25  d25

# %%
df_3 = pd.concat( [df_1, df_2]) # 합칠 데이터프레임의 리스트 default axis = 0, outer
print(df_3)
# Out:
#      A    B    C    D
# 가  a10  b10  c10  NaN
# 나  a11  b11  c11  NaN
# 다  a12  b12  c12  NaN
# 다  NaN  b23  c23  d23
# 라  NaN  b24  c24  d24
# 마  NaN  b25  c25  d25

# %%
df_4 = pd.concat( [df_1, df_2], join='inner')
print(df_4)
# Out:
#      B    C
# 가  b10  c10
# 나  b11  c11
# 다  b12  c12
# 다  b23  c23
# 라  b24  c24
# 마  b25  c25
